# %% [markdown]
# <a href="https://colab.research.google.com/github/hebermudezg/Machine-Learning/blob/master/Leer_datos_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Leer Datos
# ---
# Heber Esteban Bermúdez

# %%
# Imporatndo libreria pandas
import pandas as pd

# %%
# Cragando datos del Equipo a colaboratory
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-2e13d446-e48e-4279-a24b-f7668c5b1f04" name="files[]" multiple disabled />
#      <output id="result-2e13d446-e48e-4279-a24b-f7668c5b1f04">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving titanic3.csv to titanic3 (1).csv
# ...

# %%
# Leyendo datos
data = pd.read_csv("titanic3.csv")

# %%
# Mostrando los 3 primeros registros de la base de datos
data.head(3)
# Out:
#    pclass  survived  ... body                        home.dest
# 0       1         1  ...  NaN                     St Louis, MO
# 1       1         1  ...  NaN  Montreal, PQ / Chesterville, ON
# 2       1         0  ...  NaN  Montreal, PQ / Chesterville, ON
#
# [3 rows x 14 columns]

# %% [markdown]
# **Parámetros read_csv()**
#
# ```
# filepath (Direccion del fichero)
# sep (separador)
# header (Indice de cabecera)
# dtype ("nombre_variable_1":np.float64, "nombre_variable_2":np.int32) # requiere NumPy
# names (nombrar variables)
# skiprows (saltar filas)
# index_col (definir una columna como identificador)
# skip_blank_lines=True (la lineas en blanco seran saltadas)
# na.filter (Eliminar filas con NaN)
# ```

# %%
data = pd.read_csv(filepath_or_buffer="titanic3.csv", sep=",", dtype=None, header=0)

# %%
# Nombres de las columnas
data.columns.values
# Out:
# array(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch',
#        'ticket', 'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype=object)

# %% [markdown]
# ## Leer datos desde URL
#
# Solo basta pasar como parámetro la url a la funcion ```read_csv``` de la libreria pandas

# %%
url = "https://raw.githubusercontent.com/unalyticsteam/databases/master/titanic3.csv"
data = pd.read_csv(url)
data.head(3)
# Out:
#    pclass  survived  ... body                        home.dest
# 0       1         1  ...  NaN                     St Louis, MO
# 1       1         1  ...  NaN  Montreal, PQ / Chesterville, ON
# 2       1         0  ...  NaN  Montreal, PQ / Chesterville, ON
#
# [3 rows x 14 columns]

# %% [markdown]
# ## Cargar datos desde una hoja de cálculo. (XLS, XLSX)

# %%
# importando a colaboratory xls, xlsx
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-634c71ee-bf9a-4c48-aae1-bc7a890a1a4c" name="files[]" multiple disabled />
#      <output id="result-634c71ee-bf9a-4c48-aae1-bc7a890a1a4c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving titanic3.xls to titanic3.xls
# Saving titanic3.xlsx to titanic3.xlsx
# ...

# %%
data = pd.read_excel("titanic3.xls", sheet_name ="titanic3")
data.head(3)
# Out:
#    pclass  survived  ... body                        home.dest
# 0       1         1  ...  NaN                     St Louis, MO
# 1       1         1  ...  NaN  Montreal, PQ / Chesterville, ON
# 2       1         0  ...  NaN  Montreal, PQ / Chesterville, ON
#
# [3 rows x 14 columns]
